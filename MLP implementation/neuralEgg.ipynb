# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From c:\Users\marci\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
'''
    Importação dos arquivos.csv 
    referentes aos dados previsores 
    e suas respectivas classes
'''

previsores = pd.read_csv('inputDataset.csv')
classes = pd.read_csv('Output.csv')
print(previsores.shape)
print(classes.shape)
# Out:
# (3773, 7)
# (3773, 1)

# %%
'''
    Divisão dos dados para treinamento e teste
    * test_size indica a porcentagem de separação
      0.2 -> 20% dos dados serão destinados para teste
'''

prevTrain, prevTest, classTrain, classTest = train_test_split(previsores,classes,test_size = 0.2)
print(prevTrain.shape)
print(prevTest.shape)
print(classTrain.shape)
print(classTest.shape)
# Out:
# (3018, 7)
# (755, 7)
# (3018, 1)
# (755, 1)

# %%
'''
    Construção da rede neural
    obs: Uma rede neural densa (Dense()) indica que os neurônios de
         uma determinada camada serão ligados a todos os neurônios
         da proxima camada.

    Explicação dos parâmetros:
    * units - Define a quantidade de neurônios presentes na camada oculta
      um valor ideal (como ponto de partida) é obtido a partir 
      da media aritmética entre a quantidade de neurônios de entrada 
      (parâmetros) e a quantidade de neurônios de saídas, neste caso temos:
        (7 + 1) / 2 = 4
    
    * activation - Define qual a função de ativação para os neurônios da
      camada. 'relu' é uma função padrão para as camadas intermediárias
      e costuma retornar resultados melhores
    
    * kernel_initializer - Define a inicialização dos pesos, por padrão 
      é bom utilzar o parâmetro 'random_uniform' 

    * input_dim - Define a quantidade de valores de entrada (parâmetros)

    OBS: input_dim são utilizados APENAS na primeira
    camada oculta

'''

classificador = Sequential()
classificador.add(Dense(units = 4, 
                        activation = 'relu', 
                        kernel_initializer = 'random_uniform',
                        input_dim = 7))

'''
    Construção de novas camadas ocultas
'''

classificador.add(Dense(units = 4, 
                        activation = 'relu', 
                        kernel_initializer = 'random_uniform'))

'''
    Construção da camada de saída
'''

classificador.add(Dense(units = 1,
                        activation = 'sigmoid'))
# Out:
# WARNING:tensorflow:From c:\Users\marci\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
''' 
    Compilação da rede neural:

    * Inicialmente é feito a definição do otimizador, dessa forma, os parâmetros
      específicos do otimizador podem ser ajustados separadamente

      * learning_rate - taxa de aprendizagem (Quão drástico são os ajustes de peso)
      * decay - decremento da taxa de aprendizagem ao decorrer do tempo
      * clipvalue - parâmetro padrão dos otimizadores do keras. O clipvalue
                  tem como objetivo definir um valor max e min para os pesos

    * A compilação da rede neural aplica a estrutura definida préviamente
      
      * optimizer - Define qual o otimizador a ser aplicado
      * loss - Define a função de perda (como será feito o tratamento do erro)
      * metrics - Define como avaliar a acurácia do sistema

'''
adam = keras.optimizers.Adam(learning_rate = 0.002,
                             weight_decay = 0.0002,
                             clipvalue = 0.5)

classificador.compile(optimizer = adam,
                      loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])

''' 
    Treinamento da rede neural:

    * prevTrain - dados de treinamento
    * classTrain - classes dos dados de treinamento
    * batch_size - indica quantos registros serão processados antes da atualização de peso
    * epochs - épocas de treinamento
    
'''

classificador.fit(prevTrain,
                  classTrain,
                  batch_size = 3,
                  epochs = 100)
# Out:
# Epoch 1/100
# 1006/1006 [==============================] - 2s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 2/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 3/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 4/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 5/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 6/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 7/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 8/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 9/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 10/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 11/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 12/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 13/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 14/100
# 1006/1006 [==============================] - 2s 2ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 15/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 16/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 17/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 18/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 19/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 20/100
# 1006/1006 [==============================] - 2s 2ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 21/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 22/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 23/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 24/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 25/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 26/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 27/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 28/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 29/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3974 - binary_accuracy: 0.8641
# Epoch 30/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 31/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 32/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 33/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3977 - binary_accuracy: 0.8641
# Epoch 34/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 35/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 36/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 37/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 38/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 39/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 40/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 41/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 42/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 43/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 44/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 45/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 46/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 47/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 48/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 49/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 50/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 51/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 52/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 53/100
# 1006/1006 [==============================] - 2s 2ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 54/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 55/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 56/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 57/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 58/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 59/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 60/100
# 1006/1006 [==============================] - 2s 2ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 61/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 62/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 63/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 64/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 65/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 66/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 67/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 68/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 69/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 70/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 71/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 72/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 73/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 74/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 75/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 76/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 77/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 78/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 79/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 80/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 81/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 82/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 83/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 84/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 85/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 86/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 87/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 88/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 89/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 90/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 91/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 92/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 93/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 94/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 95/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 96/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 97/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 98/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3975 - binary_accuracy: 0.8641
# Epoch 99/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
# Epoch 100/100
# 1006/1006 [==============================] - 1s 1ms/step - loss: 0.3976 - binary_accuracy: 0.8641
